# %%
import pandas as df

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (2.1.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## pandas is installed

# %%
dd=df.read_csv(r"C:\Users\Dr Mohamadi Riaz\Desktop\jupyternotebook\Data_Gov_Tamil_Nadu.csv")
# Out:
# C:\Users\Dr Mohamadi Riaz\AppData\Local\Temp\ipykernel_10432\2120277862.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   dd=df.read_csv(r"C:\Users\Dr Mohamadi Riaz\Desktop\jupyternotebook\Data_Gov_Tamil_Nadu.csv")

# %% [markdown]
# ## Data is imported

# %%
dd.head()
# Out:
#   CORPORATE_IDENTIFICATION_NUMBER  \
# 0                          F00643
# 1                          F00721
# 2                          F00892
# 3                          F01208
# 4                          F01218
#
#                                         COMPANY_NAME COMPANY_STATUS  \
# 0                                   HOCHTIEFF AG,              NAEF
# 1  SUMITOMO CORPORATION (SUMITOMO SHOJI KAISHA LI...           ACTV
# 2                      SRILANKAN AIRLINES LIMITED              ACTV
# 3                            CALTEX INDIA LIMITED              NAEF
# 4              GE HEALTHCARE BIO-SCIENCES LIMITED              ACTV
#
#   COMPANY_CLASS COMPANY_CATEGORY COMPANY_SUB_CATEGORY DATE_OF_REGISTRATION  \
# 0           NaN              NaN                  NaN            1/12/1961
# 1           NaN              NaN                  NaN                  NaN
# 2           NaN              NaN                  NaN             1/3/1982
# 3           NaN              NaN                  NaN                  NaN
# 4           NaN              NaN                  NaN                  NaN
#
#   REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL INDUSTRIAL_CLASS  \
# 0       Tamil Nadu             0.0             0.0              NaN
# 1       Tamil Nadu             0.0             0.0              NaN
# 2       Tamil Nadu             0.0             0.0              NaN
# 3       Tamil Nadu             0.0             0.0              NaN
# 4       Tamil Nadu             0.0             0.0              NaN
#
#   PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0                   Agriculture & allied
# 1                   Agriculture & allied
# 2                   Agriculture & allied
# 3                   Agriculture & allied
# 4                   Agriculture & allied
#
#                            REGISTERED_OFFICE_ADDRESS REGISTRAR_OF_COMPANIES  \
# 0  AMBLE SIDE, NO.8(OLD NO.30),3RD FLOOR KHADER N...              ROC DELHI
# 1  FLAT NO. 6, 1st FLOOR, 113/113ARAMA NAICKEN ST...              ROC DELHI
# 2  SRILANKAN AIRLINES LIMITED, VIJAYA TOWERSNO-4,...              ROC DELHI
# 3         GOLD CREST 24 55 NORTHUSMAN ROAD T NAGAR                ROC DELHI
# 4   FF-3 Palani  Centre32 Venkat Naryan Road Nagar                ROC DELHI
#
#                EMAIL_ADDR LATEST_YEAR_ANNUAL_RETURN  \
# 0                     NaN                       NaN
# 1      shuchi.chug@asa.in                       NaN
# 2     shree16us@yahoo.com                       NaN
# 3                     NaN                       NaN
# 4  karthick9999@yahoo.com                       NaN
#
#   LATEST_YEAR_FINANCIAL_STATEMENT
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %% [markdown]
# ## head()- Returns the first 5 rows of the dataset

# %%
dd.drop_duplicates()
# Out:
#        CORPORATE_IDENTIFICATION_NUMBER  \
# 0                               F00643
# 1                               F00721
# 2                               F00892
# 3                               F01208
# 4                               F01218
# ...                                ...
# 150866           U74997TN2016PTC112556
# 150867           U74997TN2018PTC121491
# 150868           U74997TZ2016PTC027802
# 150869           U74997TZ2018PTC030177
# 150870           U74997TZ2019PTC032491
#
#                                              COMPANY_NAME COMPANY_STATUS  \
# 0                                        HOCHTIEFF AG,              NAEF
# 1       SUMITOMO CORPORATION (SUMITOMO SHOJI KAISHA LI...           ACTV
# 2                           SRILANKAN AIRLINES LIMITED              ACTV
# 3                                 CALTEX INDIA LIMITED              NAEF
# 4                   GE HEALTHCARE BIO-SCIENCES LIMITED              ACTV
# ...                                                   ...            ...
# 150866                    QUAD42 MEDIA PRIVATE LIMITED              ACTV
# 150867                 IYERAATHU FOODS PRIVATE LIMITED              ACTV
# 150868          POLYGAR FARM SOLUTIONS PRIVATE LIMITED              STOF
# 150869          PANDIYA AGRI SOLUTIONS PRIVATE LIMITED              ACTV
# 150870              NROOT TECHNOLOGIES PRIVATE LIMITED              ACTV
#
#        COMPANY_CLASS           COMPANY_CATEGORY COMPANY_SUB_CATEGORY  \
# 0                NaN                        NaN                  NaN
# 1                NaN                        NaN                  NaN
# 2                NaN                        NaN                  NaN
# 3                NaN                        NaN                  NaN
# 4                NaN                        NaN                  NaN
# ...              ...                        ...                  ...
# 150866       Private  Company limited by Shares     Non-govt company
# 150867       Private  Company limited by Shares     Non-govt company
# 150868       Private  Company limited by Shares     Non-govt company
# 150869       Private  Company limited by Shares     Non-govt company
# 150870       Private  Company limited by Shares     Non-govt company
#
#        DATE_OF_REGISTRATION REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL  \
# 0                 1/12/1961       Tamil Nadu             0.0             0.0
# 1                       NaN       Tamil Nadu             0.0             0.0
# 2                  1/3/1982       Tamil Nadu             0.0             0.0
# 3                       NaN       Tamil Nadu             0.0             0.0
# 4                       NaN       Tamil Nadu             0.0             0.0
# ...                     ...              ...             ...             ...
# 150866           19-09-2016       Tamil Nadu       1000000.0        100000.0
# 150867           16-03-2018       Tamil Nadu        100000.0        100000.0
# 150868           20-07-2016       Tamil Nadu        100000.0         20000.0
# 150869           16-03-2018       Tamil Nadu       2500000.0       1500000.0
# 150870           25-07-2019       Tamil Nadu       1500000.0       1100000.0
#
#        INDUSTRIAL_CLASS       PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0                   NaN                         Agriculture & allied
# 1                   NaN                         Agriculture & allied
# 2                   NaN                         Agriculture & allied
# 3                   NaN                         Agriculture & allied
# 4                   NaN                         Agriculture & allied
# ...                 ...                                          ...
# 150866            74997  Real estate renting and business activities
# 150867            74997  Real estate renting and business activities
# 150868            74997  Real estate renting and business activities
# 150869            74997  Real estate renting and business activities
# 150870            74997  Real estate renting and business activities
#
#                                 REGISTERED_OFFICE_ADDRESS  \
# 0       AMBLE SIDE, NO.8(OLD NO.30),3RD FLOOR KHADER N...
# 1       FLAT NO. 6, 1st FLOOR, 113/113ARAMA NAICKEN ST...
# 2       SRILANKAN AIRLINES LIMITED, VIJAYA TOWERSNO-4,...
# 3              GOLD CREST 24 55 NORTHUSMAN ROAD T NAGAR
# 4        FF-3 Palani  Centre32 Venkat Naryan Road Nagar
# ...                                                   ...
# 150866      Old No.37, New No.5753rd Street, 9th Avenue
# 150867  G-3, G-Block, AKS Garden,11/1, 2nd Street Rama...
# 150868             31, LIC Colony (VOC Colony),Kurichi,
# 150869  10/10 C3, Venkatasamy StreetRailyway Mens Colo...
# 150870   139/1BPUDHUKOTTAI ROAD, MAPILLAI NAYAKKANPATTI
#
#        REGISTRAR_OF_COMPANIES                   EMAIL_ADDR  \
# 0                   ROC DELHI                          NaN
# 1                   ROC DELHI           shuchi.chug@asa.in
# 2                   ROC DELHI          shree16us@yahoo.com
# 3                   ROC DELHI                          NaN
# 4                   ROC DELHI       karthick9999@yahoo.com
# ...                       ...                          ...
# 150866            ROC CHENNAI             ezhil@quad42.com
# 150867            ROC CHENNAI     sneha.creative@gmail.com
# 150868         ROC COIMBATORE    prashanthramana@gmail.com
# 150869         ROC COIMBATORE     sathishpandiya@gmail.com
# 150870         ROC COIMBATORE  nroottechnologies@gmail.com
#
#        LATEST_YEAR_ANNUAL_RETURN LATEST_YEAR_FINANCIAL_STATEMENT
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
# ...                          ...                             ...
# 150866                31-03-2019                      31-03-2019
# 150867                       NaN                             NaN
# 150868                       NaN                             NaN
# 150869                31-03-2019                      31-03-2019
# 150870                       NaN                             NaN
#
# [150871 rows x 17 columns]

# %% [markdown]
# ## drop_duplicates() - removes duplicate rows in the dataset

# %%
dd.dropna(inplace=True)

# %% [markdown]
# ## dropna() - Removes rows which contain null value

# %%
dd['COMPANY_NAME']=dd['COMPANY_NAME'].str.lower()

# %% [markdown]
# ## All values in 'COMPANY_NAME' is changed into lowercase

# %%
dd['DATE_OF_REGISTRATION']=df.to_datetime(dd['DATE_OF_REGISTRATION'])
# Out:
# C:\Users\Dr Mohamadi Riaz\AppData\Local\Temp\ipykernel_10432\3927820756.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   dd['DATE_OF_REGISTRATION']=df.to_datetime(dd['DATE_OF_REGISTRATION'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 dd['DATE_OF_REGISTRATION']=df.to_datetime(dd['DATE_OF_REGISTRATION'])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:1112, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1110         result = arg.map(cache_array)
#    1111     else:
# -> 1112         values = convert_listlike(arg._values, format)
#    1113         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1114 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:488, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     486 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     487 if format is not None and format != "mixed":
# --> 488     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     490 result, tz_parsed = objects_to_datetime64ns(
#     491     arg,
#     492     dayfirst=dayfirst,
#    (...)
#     496     allow_object=True,
#     497 )
#     499 if tz_parsed is not None:
#     500     # We can take a shortcut since the datetime64 numpy array
#     501     # is in UTC
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:519, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     508 def _array_strptime_with_fallback(
#     509     arg,
#     510     name,
#    (...)
#     514     errors: str,
#     515 ) -> Index:
#     516     """
#     517     Call array_strptime, with fallback behavior depending on 'errors'.
#     518     """
# --> 519     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     520     if any(tz is not None for tz in timezones):
#     521         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File strptime.pyx:534, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:355, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "4/5/1995" doesn't match format "%d-%m-%Y", at position 3. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %% [markdown]
# ## Convert string Date to Python Date time object

# %%
dd1=dd.set_index('DATE_OF_REGISTRATION')

# %% [markdown]
# ## Index is set

# %%
numeric_columns=dd1.select_dtypes(include=['number'])

# %% [markdown]
# ## Returns the new dataframe that includes the column 'number'

# %%
dd_resampled=numeric_columns.resample('M').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 dd_resampled=numeric_columns.resample('M').mean()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:9435, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    9432 else:
#    9433     axis = 0
# -> 9435 return get_resampler(
#    9436     cast("Series | DataFrame", self),
#    9437     freq=rule,
#    9438     label=label,
#    9439     closed=closed,
#    9440     axis=axis,
#    9441     kind=kind,
#    9442     convention=convention,
#    9443     key=on,
#    9444     level=level,
#    9445     origin=origin,
#    9446     offset=offset,
#    9447     group_keys=group_keys,
#    9448 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\resample.py:1970, in get_resampler(obj, kind, **kwds)
#    1966 """
#    1967 Create a TimeGrouper and return our resampler.
#    1968 """
#    1969 tg = TimeGrouper(**kwds)
# -> 1970 return tg._get_resampler(obj, kind=kind)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\resample.py:2160, in TimeGrouper._get_resampler(self, obj, kind)
#    2151 elif isinstance(ax, TimedeltaIndex):
#    2152     return TimedeltaIndexResampler(
#    2153         obj,
#    2154         timegrouper=self,
#    (...)
#    2157         gpr_index=ax,
#    2158     )
# -> 2160 raise TypeError(
#    2161     "Only valid with DatetimeIndex, "
#    2162     "TimedeltaIndex or PeriodIndex, "
#    2163     f"but got an instance of '{type(ax).__name__}'"
#    2164 )
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'

# %% [markdown]
# ## Data is resampled based on month frequency

# %%
dd.to_csv('NewCleanedFile.csv',index=False)
dd
# Out:
#        CORPORATE_IDENTIFICATION_NUMBER  \
# 310              L01117TZ1943PLC000117
# 311              L01119TN1986PLC013473
# 313              L01119TN1992PLC024076
# 315              L01122TZ1995PLC010762
# 318              L01132TZ1922PLC000234
# ...                                ...
# 150862           U74997TN2016PTC112105
# 150864           U74997TN2016PTC112257
# 150865           U74997TN2016PTC112312
# 150866           U74997TN2016PTC112556
# 150869           U74997TZ2018PTC030177
#
#                                            COMPANY_NAME COMPANY_STATUS  \
# 310               neelamalai agro industries limited              ACTV
# 311                            aban offshore limited              ACTV
# 313               softech infinium solutions limited              ACTV
# 315                     pochiraju industries limited              ACTV
# 318     the united nilgiri tea estates companylimited             ACTV
# ...                                                 ...            ...
# 150862           mrkr communications private limited              ACTV
# 150864     ethnicindian fashion retail privatelimited             ACTV
# 150865             savidya education private limited              ACTV
# 150866                  quad42 media private limited              ACTV
# 150869        pandiya agri solutions private limited              ACTV
#
#        COMPANY_CLASS           COMPANY_CATEGORY COMPANY_SUB_CATEGORY  \
# 310           Public  Company limited by Shares     Non-govt company
# 311           Public  Company limited by Shares     Non-govt company
# 313           Public  Company limited by Shares     Non-govt company
# 315           Public  Company limited by Shares     Non-govt company
# 318           Public  Company limited by Shares     Non-govt company
# ...              ...                        ...                  ...
# 150862       Private  Company limited by Shares     Non-govt company
# 150864       Private  Company limited by Shares     Non-govt company
# 150865       Private  Company limited by Shares     Non-govt company
# 150866       Private  Company limited by Shares     Non-govt company
# 150869       Private  Company limited by Shares     Non-govt company
#
#        DATE_OF_REGISTRATION REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL  \
# 310              21-04-1943       Tamil Nadu    1.250000e+07       6273500.0
# 311              25-09-1986       Tamil Nadu    1.500000e+10     116730000.0
# 313              21-12-1992       Tamil Nadu    1.500000e+08      40000000.0
# 315                4/5/1995       Tamil Nadu    2.500000e+08     189066750.0
# 318                9/8/1922       Tamil Nadu    5.000000e+07      49965660.0
# ...                     ...              ...             ...             ...
# 150862           22-08-2016       Tamil Nadu    1.000000e+05        100000.0
# 150864           30-08-2016       Tamil Nadu    1.000000e+06       1000000.0
# 150865             1/9/2016       Tamil Nadu    1.000000e+06        100000.0
# 150866           19-09-2016       Tamil Nadu    1.000000e+06        100000.0
# 150869           16-03-2018       Tamil Nadu    2.500000e+06       1500000.0
#
#        INDUSTRIAL_CLASS       PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 310                1117                         Agriculture & allied
# 311                1119                         Agriculture & allied
# 313                1119                         Agriculture & allied
# 315                1122                         Agriculture & allied
# 318                1132                         Agriculture & allied
# ...                 ...                                          ...
# 150862            74997  Real estate renting and business activities
# 150864            74997  Real estate renting and business activities
# 150865            74997  Real estate renting and business activities
# 150866            74997  Real estate renting and business activities
# 150869            74997  Real estate renting and business activities
#
#                                 REGISTERED_OFFICE_ADDRESS  \
# 310                     KATARY ESTATEKATARY POSTCOONOOR
# 311            'JANPRIYA CREST'96, PANTHEON ROAD,EGMORE
# 313     29, PRECISION PLAZA, NEW 397, ANNA SALAITEYNAM...
# 315             1/102 SATHYAMANGALAM VILLAGEHOSUR TALUK
# 318               3 SAVITHRI SHANMUGHAM ROADRACE COURSE
# ...                                                   ...
# 150862  11C,AASARI STREET,THALLAKULAM11C,AASARI STREET...
# 150864  VNR Milford, Flat 117, First FloorA Block, Mil...
# 150865  Mahalakshmi Mansion, 29/4 FirstMain Road ,Gand...
# 150866      Old No.37, New No.5753rd Street, 9th Avenue
# 150869  10/10 C3, Venkatasamy StreetRailyway Mens Colo...
#
#        REGISTRAR_OF_COMPANIES                             EMAIL_ADDR  \
# 310            ROC COIMBATORE     secneelamalai@avtplantations.co.in
# 311               ROC CHENNAI                   secretarial@aban.com
# 313               ROC CHENNAI  complianceofficer@softechinfinium.com
# 315            ROC COIMBATORE                 mmreddyandco@gmail.com
# 318            ROC COIMBATORE              headoffice@chamrajtea.com
# ...                       ...                                    ...
# 150862            ROC CHENNAI                    RKRPRIYAN@GMAIL.COM
# 150864            ROC CHENNAI                ALEX.CHANDRAN@GMAIL.COM
# 150865            ROC CHENNAI                   sridevis77@yahoo.com
# 150866            ROC CHENNAI                       ezhil@quad42.com
# 150869         ROC COIMBATORE               sathishpandiya@gmail.com
#
#        LATEST_YEAR_ANNUAL_RETURN LATEST_YEAR_FINANCIAL_STATEMENT
# 310                   31-03-2019                      31-03-2019
# 311                   31-03-2019                      31-03-2019
# 313                   31-03-2018                      31-03-2018
# 315                   31-03-2019                      31-03-2019
# 318                   31-03-2019                      31-03-2019
# ...                          ...                             ...
# 150862                31-03-2019                      31-03-2019
# 150864                31-03-2019                      31-03-2019
# 150865                31-03-2019                      31-03-2019
# 150866                31-03-2019                      31-03-2019
# 150869                31-03-2019                      31-03-2019
#
# [73739 rows x 17 columns]

# %% [markdown]
# ## The cleaned data is stored in new file

# %%
dd1=df.read_csv(r"C:\Users\Dr Mohamadi Riaz\Desktop\jupyternotebook\NewCleanedFile.csv")

# %% [markdown]
# ## The cleaned file is saved and read in the given path

# %%
pip install matplotlib.pyplot
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## matplotlib is installed

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## matplotlib is imported as plt

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (0.13.0)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (1.26.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\dr mohamadi riaz\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)

# %% [markdown]
# ## seaborn is installed

# %%
import seaborn as sns

# %% [markdown]
# ## seaborn is imported

# %%
sns.histplot(dd1['DATE_OF_REGISTRATION'],bins=20,kde=True)
plt.title('DATE_OF_REGISTRATION')
plt.xlabel('DATE_OF_REGISTRATION')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Histogram is plotted

# %%
dd1.describe()
# Out:
#        AUTHORIZED_CAP  PAIDUP_CAPITAL  INDUSTRIAL_CLASS
# count    7.373900e+04    7.373900e+04      73739.000000
# mean     6.893708e+07    4.676698e+07      53227.012382
# std      2.013478e+09    1.533597e+09      23985.340312
# min      0.000000e+00    0.000000e+00          0.000000
# 25%      2.000000e+05    1.000000e+05      30007.000000
# 50%      1.000000e+06    4.000000e+05      63013.000000
# 75%      5.000000e+06    2.740000e+06      73100.000000
# max      3.000000e+11    2.461230e+11      99999.000000

# %% [markdown]
# ## Data is analysed using describe()

# %%
category_count=dd1['COMPANY_CLASS'].value_counts()
plt.figure(figsize=(6,6))
sns.set_palette("Set3")
plt.pie(category_count,labels=category_count.index,autopct='%1.1f%%', startangle=140)
plt.title("Company class distribution")
plt.show()

# %% [markdown]
# ## Pie chart is plotted

# %% [markdown]
# ## Bar chart is plotted

# %%
import pandas as df
dd1=df.read_csv(r"C:\Users\Dr Mohamadi Riaz\Desktop\jupyternotebook\NewCleanedFile.csv")
import matplotlib.pyplot as plt
x=dd1['INDUSTRIAL_CLASS']
y=dd1['LATEST_YEAR_ANNUAL_RETURN']
dd1
plt.plot(x,y,marker='o',linestyle='-',color='b',label='Value series')
plt.xlabel('Industrial class')
plt.ylabel('latest year annual return')
plt.title('Line chart')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Line chart is plotted

# %%
import pandas as df
dd1=df.read_csv(r"C:\Users\Dr Mohamadi Riaz\Desktop\jupyternotebook\NewCleanedFile.csv")
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,6))
sns.boxplot(data=dd1, x='COMPANY_STATUS', y='AUTHORIZED_CAP')
plt.title('Boxplot of Authorized Capital by Company Status')
plt.xlabel('Company Status')
plt.ylabel('Authorized Capital')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as df
dd1=df.read_csv(r"C:\Users\Dr Mohamadi Riaz\Desktop\jupyternotebook\NewCleanedFile.csv")
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,6))
sns.countplot(data=dd1,  x="REGISTRAR_OF_COMPANIES")
plt.title('Distribution of Registrar of Companies')
plt.xlabel('Registrar of Companies')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as df
dd1=df.read_csv(r"C:\Users\Dr Mohamadi Riaz\Desktop\jupyternotebook\NewCleanedFile.csv")
import matplotlib.pyplot as plt
categories=dd1['COMPANY_NAME']
values=dd1['INDUSTRIAL_CLASS']
plt.bar(categories,values)
plt.xlabel('Company name')
plt.ylabel('Industrial Class')
plt.title('Bar chart for Company name and Industrial Class')
plt.show()
